# %% [markdown]
# # Plots for the results chapter

# %%
from rootpy.io import root_open
from rootpy import asrootpy
from rootpy.plotting import root2matplotlib as rplt
from rootpy.plotting import Canvas


import sys
sys.path.append('/home/christian/msc/analysis/pyproof/post_analysis/')
#import ROOT
#from bg_sig_total_yield import calc_bg, calc_signal_and_total_yield
#from post_subtraction import high_minus_low
# %load_ext autoreload
# %autoreload 2

from post_efficiencies import calc_effs, get_2d_eff_from_signal, get_2d_eff_from_bg
from fit_2d import fit_2d_efficiency, func_to_hist
from combi_plot import mega_plot, _plot_x_projection
from extract_yield import extract_yield


# rcParams dict
import matplotlib as mpl
import matplotlib.pyplot as plt
colors = [(0.4, 0.7607843137254902, 0.6470588235294118), (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
          (0.5529411764705883, 0.6274509803921569, 0.796078431372549), (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
          (0.6509803921568628, 0.8470588235294118, 0.32941176470588235), (1.0, 0.8509803921568627, 0.1843137254901961),
          (0.8980392156862745, 0.7686274509803922, 0.5803921568627451)]
mpl.rcParams['axes.color_cycle'] = colors

font_params = {"axes.labelsize": 8,
                "axes.titlesize": 9,
                "xtick.labelsize": 8,
                "ytick.labelsize": 8,
                "legend.fontsize": 8,
                'font.family': 'serif',
                'text.usetex': True,
                'font.serif': 'Computer Modern Roman',
                }
mpl.rcParams.update(font_params)

ticksize = 3.
tickwidth = .5
ax_params = {"axes.grid": False,
             "axes.facecolor": "white",
             "axes.edgecolor": "black",
             "axes.linewidth": 1,
             "xtick.direction": "in",
             "ytick.direction": "in",
             "xtick.major.width": tickwidth,
             "ytick.major.width": tickwidth,
             "xtick.minor.width": tickwidth,
             "xtick.minor.width": tickwidth,
             "xtick.major.size": ticksize,
             "xtick.minor.size": ticksize / 2,
             "ytick.major.size": ticksize,
             "ytick.minor.size": ticksize / 2}
mpl.rcParams.update(ax_params)

mpl.rcParams.update({
    "lines.linewidth": 1.1 ,
    "patch.linewidth": .1 ,
    "xtick.major.pad": 3.5 ,
    "ytick.major.pad": 3.5 ,
    })

# Set the constant defaults
mpl.rc("legend", frameon=False, numpoints=1)
mpl.rc("lines", markeredgewidth=0, solid_capstyle="round")
mpl.rc("figure", figsize=(2.95,2.95))
#mpl.rc("image", cmap="cubehelix")
mpl.rc("image", cmap="jet")
mpl.rcParams['text.latex.preamble']=[r"\usepackage{siunitx}",]


#helpers
pta = r'p_{\text{T}}^{\text{asso}}'
ptt = r'p_{\text{T}}^{\text{trig}}'
pthresh = r'p_{\text{T}}^{\text{tresh}}'

cs = ['($0-20\%$)', '($20-40\%$)', '($40-60\%$)', '($60-100\%$)']
# Out:
# INFO:rootpy.plotting.style:using matplotlib style 'ATLAS'

# %% [markdown]
# ## Which intervals should be used?

# %% [markdown]
# * Yield extractio needs equal intervals!
#     - 1 -2 GeV for both, has room for threshold, and significant values for v2 and v3 (comp. to 0.5-1)
# * I should include 0.5-1 1-2 since I have most experiance there and old plots from pag presentation to compair changes

# %% [markdown]
# ### Event classes for 1-2 2-4, show how long range deta emerges

# %%
#f_real = root_open('/home/christian/msc/results/140113/TPC_05-1_1-2/output_real.root', 'read')
f_12_real = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_real.root', 'read')
figsize= (2.95,2.95)

# Signal ratios:

eclass = 0
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$1 <' +pta+'< \SI{2}{GeV}<'+ptt+'<\SI{4}{GeV}$'
mega_plot(h, exclude_peak=True, range_2d=(1.0, 1.2), yrange_px=(1.02, 1.17))
#plt.savefig('12_24_class' + str(eclass)+'.pdf')
plt.show()

eclass = 1
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$1 <' +pta+'< \SI{2}{GeV}<'+ptt+'<\SI{4}{GeV}$'
mega_plot(h, exclude_peak=True, range_2d=(.6, .8), yrange_px=(.55, .8))#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
#plt.savefig('12_24_class' + str(eclass)+'.pdf')
plt.show()

eclass = 2
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$1 <' +pta+'< \SI{2}{GeV}<'+ptt+'<\SI{4}{GeV}$'
mega_plot(h, exclude_peak=True, range_2d=(.39, .59), yrange_px=(.34, .67))#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
#plt.savefig('12_24_class' + str(eclass)+'.pdf')
plt.show()

eclass = 3
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$1 <' +pta+'< \SI{2}{GeV}<'+ptt+'<\SI{4}{GeV}$'
mega_plot(h, exclude_peak=True, range_2d=(.2, .4), yrange_px=(.15, .5))#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
#plt.savefig('12_24_class' + str(eclass)+'.pdf')
plt.show()

h.drawstyle = 'surf1'

# %% [markdown]
# ### Subtractions Without pt threshold 1-2 2-4 (updates to pag)

# %%
#f_real = root_open('/home/christian/msc/results/140113/TPC_05-1_1-2/output_real.root', 'read')
f_12_real = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_real.root', 'read')
figsize= (2.95,2.95)

# Signal ratios:
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.subtracted_corrected.Get('Subtraction_thresh_0.0')
h.title = '$(60-100\%) - (0-20\%)$'
mega_plot(h, exclude_peak=True, plot_fit=False)#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
#plt.savefig('closure_S_peri_st.pdf')
plt.show()

h.Delete()

# %% [markdown]
# ### 2D plot as shown in pag

# %%
c = Canvas()
c.Size(7.5, 7.5)
pad = c.pad()

pad.SetTheta(50)
pad.SetPhi(45)
pad.SetLeftMargin(0.2)
pad.SetRightMargin(0.05)
pad.SetTopMargin(0.05)
pad.SetBottomMargin(0.05)

h = f_12_real.processed.subtracted_corrected.Get('Subtraction_thresh_0.0')
h.Draw('surf1')
h.set_x_title(h.xaxis.title)
h.set_y_title(h.yaxis.title)
h.set_z_title('#frac{1}{N_{trig}} #frac{d^{2}N_{assoc}}{d#Delta#eta d#Delta#varphi}')
h.Draw('surf1')
h.SetStats(0)
h.xaxis.CenterTitle()
h.xaxis.SetTitleOffset(1.5)

h.yaxis.CenterTitle()
h.yaxis.SetTitleOffset(1.5)

h.zaxis.CenterTitle()
h.zaxis.SetTitleOffset(2.2)
h.title = ''
c.SaveAs('subtraction_12_24_nothresh.pdf')
c
# Out:
# Canvas('e7e4d4637cc940af88d99bc4b795c00f')

# %% [markdown]
# #### dphi projection with mc baseline

# %%
t = 0.0
f_eff = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_effs.root', 'read')
f_re = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_reconstructed.root', 'read')
f_12_real = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_real.root', 'read')

eff0 = asrootpy(f_eff.processed.eff_from_ty.get('eff_yield_class_' + str(0) + '_thresh_' + str(t)))
eff3 = asrootpy(f_eff.processed.eff_from_ty.get('eff_yield_class_' + str(3) + '_thresh_' + str(t)))
h0_re = f_re.processed.total_yield.Get('total_yield_class_0_thresh_0.0')
h3_re = f_re.processed.total_yield.Get('total_yield_class_3_thresh_0.0')

h_real = f_12_real.processed.subtracted_corrected.Get('Subtraction_thresh_0.0')

fit_2d_efficiency(eff0)
f0 = eff0.GetFunction('peak')
fit_2d_efficiency(eff3)
f3 = eff3.GetFunction('peak')

h_re = h0_re/f0 - h3_re/f3
h_px_re = extract_yield(h_re)[0]
h_px_real = extract_yield(h_real)[0]
zyam = h_px_real.GetBinContent(h_px_real.FindBin(1.3))

shift = zyam - average(list(h_px_re.y()))
# Out:
# Reduced chi^2:  0.452855438511
# Reduced chi^2:
#  0.503792902187

# %%
plt.close('all')
figsize= (2.95,2.95*.627)

# Signal ratios:
plt.close('all')
fig = plt.figure(figsize=figsize)

ax = plt.subplot(111)
plt.subplots_adjust(right=1, top=1.0, bottom=.12, )#left=.12)
ax.set_xlabel('$\Delta \phi [rad]$')
ax.minorticks_on()

lns = []
h = f_12_real.processed.subtracted_corrected.Get('Subtraction_thresh_0.0')

h_px_re.color = colors[-1]
lns.append(rplt.errorbar(h_px_re + shift, marker='s', fillstyle='none', axes=ax))

_plot_x_projection(h, (0.81, .935), 'data', ax, lns, True, True, None )
#h.Delete()
labels = ['HIJING shifted', 'data',
          '$a_0 + 2a_2 \cos (2\Delta \phi )$',
          '$a_0 + 2a_2 \cos (2\Delta \phi )+ 2a_3 \cos (3\Delta \phi )$']
#ax.set_ylim(top=0.91)
plt.legend(lns, labels, loc=0)

ax.xaxis.labelpad = 0
fig.savefig('subtraction_px_12_24_nothresh.pdf')
plt.show()

# %% [markdown]
# ### Evolution of dphi projections excluding phi (<- thats a difference to pag pres.)

# %%
f_051_t0 = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_real.root', 'read')
f_051_t2 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_real.root', 'read')
f_051_t3 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_3/output_real.root', 'read')
f_051_t4 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_4/output_real.root', 'read')

plt.close('all')
figsize= (2.95*2,2.95)

# Signal ratios:
plt.close('all')

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharex=True, sharey=True, figsize=figsize, )
for a in fig.axes:
    a.set_xlabel(r'$\Delta \varphi [rad]$')
    a.minorticks_on()
    #a.grid(True)
ax1.set_ylabel(r'$\frac{1}{N_{tr}}\frac{dN_{as}}{d\Delta \varphi}$'
              '[rad$^{-1}$]')


lns = []
t=0.0
ax = ax1
f = f_051_t0
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t)))
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title(r'No high $p_{\text{T}}$ threshold')

t=2.0
ax = ax2
f = f_051_t2
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t)))
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')

t=3.0
ax = ax3
f = f_051_t3
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t)))
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')

t=4.0
ax = ax4
f = f_051_t4
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t)))
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')


fig.subplots_adjust(wspace=0)
#plt.setp([a.get_xticklabels() for a in fig.axes[:-1]], visible=False)
ax1.set_ylim(.4, 2.3)
ax1.legend(loc=0, )
fig.tight_layout()
#fig.savefig('y_px_evolution_with_threshold.pdf')
plt.show()

# %% [markdown]
# ## Division of projections by 0 thresh case

# %%
f_051_t0 = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_real.root', 'read')
f_051_t2 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_real.root', 'read')
f_051_t3 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_3/output_real.root', 'read')
f_051_t4 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_4/output_real.root', 'read')

plt.close('all')
figsize= (2.95/2*3,2.95)

# Signal ratios:
plt.close('all')

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True, sharey=True, figsize=figsize, )
for a in fig.axes:
    a.set_xlabel(r'$\Delta \varphi [rad]$')
    #a.minorticks_on()
    #a.grid(True)
ax1.set_ylabel(r'Ratio $Y^{thresh} / Y^{no thresh}$')

hists_base = []
for c in range(0, 4):
    hists_base.append(asrootpy(f_051_t0.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_0.0')))


lns = []
t=2.0
ax = ax1
f = f_051_t2
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t))) / hists_base[c]
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')

t=3.0
ax = ax2
f = f_051_t3
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t))) / hists_base[c]
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')

t=4.0
ax = ax3
f = f_051_t4
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t))) / hists_base[c]
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    if c == 3:  # rebin peripheral
        h_px.Rebin()
        h_px.Scale(1.0 / 2.0)
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')


fig.subplots_adjust(wspace=0)
#plt.setp([a.get_xticklabels() for a in fig.axes[:-1]], visible=False)
ax1.set_ylim(1.0, 1.45)
ax1.legend(loc=0, )
fig.tight_layout()
fig.savefig('y_px_evolution_with_threshold_div_by_thresh0.pdf')
plt.show()

# %% [markdown]
# ## 2D subtraction with threshold

# %%
f_051_t0 = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_real.root', 'read')
f_051_t2 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_real.root', 'read')
f_051_t3 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_3/output_real.root', 'read')
f_051_t4 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_4/output_real.root', 'read')
f_051_t5 = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_5/output_real.root', 'read')
exclude_peak=True
figsize= (2.95,2.95)
#+ pthresh + r'$=\SI{' + str(t) + '}{GeV}$'

t = 0.0
f= f_051_t0
f_re = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_reconstructed.root', 'read')

plt.close('all')
fig = plt.figure(figsize=figsize)
h = f.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t))
h.title = cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$\n' + pthresh + '$=\SI{' + str(t) + '}{GeV}$'
sub_px_re = extract_yield(f_re.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t)), exclude_peak=exclude_peak)[0]
sub_px_real = extract_yield(h)[0]
zyam_real = sub_px_real.Integral(sub_px_real.FindBin(1.3)-1, sub_px_real.FindBin(1.3)+1) /3.0
zyam_re = sub_px_re.Integral(sub_px_re.FindBin(1.3)-1, sub_px_re.FindBin(1.3)+1) /3.0
scale = zyam_re / zyam_real
print 'scale', scale 
mega_plot(h, exclude_peak=exclude_peak, range_2d=(1.25, 1.45), yrange_px=(1.27, 1.34))
plt.savefig('05_12_sub_thresh_' + str(t).replace('.', '') +'no_extra.pdf')
plt.show()


t = 0.0
f= f_051_t0
f_re = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_reconstructed.root', 'read')

plt.close('all')
fig = plt.figure(figsize=figsize)
h = f.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t))
h.title = cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$\n' + pthresh + '$=\SI{' + str(t) + '}{GeV}$'
sub_px_re = extract_yield(f_re.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t)), exclude_peak=exclude_peak)[0]
sub_px_real = extract_yield(h)[0]
zyam_real = sub_px_real.Integral(sub_px_real.FindBin(1.3)-1, sub_px_real.FindBin(1.3)+1) /3.0
zyam_re = sub_px_re.Integral(sub_px_re.FindBin(1.3)-1, sub_px_re.FindBin(1.3)+1) /3.0
scale = zyam_re / zyam_real
print 'scale', scale 
dphi_extra=asrootpy(sub_px_re)
dphi_extra.title = 'MC rec'
mega_plot(h, exclude_peak=exclude_peak, range_2d=(1.25, 1.45), yrange_px=(1.27, 1.34), dphi_extra=dphi_extra / scale)
plt.savefig('05_12_sub_thresh_' + str(t).replace('.', '') +'.pdf')
plt.show()


t = 2.0
f= f_051_t2
plt.close('all')
f_re = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_reconstructed.root', 'read')

fig = plt.figure(figsize=figsize)
h = f.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t))
h.title = cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$\n' + pthresh + '$=\SI{' + str(t) + '}{GeV}$'
sub_px_re = extract_yield(f_re.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t)), exclude_peak=exclude_peak)[0]
sub_px_real = extract_yield(h)[0]
zyam_real = sub_px_real.Integral(sub_px_real.FindBin(1.3)-1, sub_px_real.FindBin(1.3)+1) /3.0
zyam_re = sub_px_re.Integral(sub_px_re.FindBin(1.3)-1, sub_px_re.FindBin(1.3)+1) /3.0
scale = zyam_re / zyam_real
print 'scale', scale 
dphi_extra=asrootpy(sub_px_re)
dphi_extra.title = 'MC rec'
mega_plot(h, exclude_peak=exclude_peak, range_2d=(1.25, 1.45), yrange_px=(1.285, 1.355), dphi_extra=dphi_extra / scale)
plt.savefig('05_12_sub_thresh_' + str(t).replace('.', '') +'.pdf')
plt.show()

t = 3.0
f= f_051_t3
plt.close('all')
f_re = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_3/output_reconstructed.root', 'read')
fig = plt.figure(figsize=figsize)
h = f.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t))
h.title = cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$\n' + pthresh + '$=\SI{' + str(t) + '}{GeV}$'
sub_px_re = extract_yield(f_re.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t)), exclude_peak=exclude_peak)[0]
sub_px_real = extract_yield(h)[0]
zyam_real = sub_px_real.Integral(sub_px_real.FindBin(1.3)-1, sub_px_real.FindBin(1.3)+1) /3.0
zyam_re = sub_px_re.Integral(sub_px_re.FindBin(1.3)-1, sub_px_re.FindBin(1.3)+1) /3.0
scale = zyam_re / zyam_real
print 'scale', scale 
dphi_extra=asrootpy(sub_px_re)
dphi_extra.title = 'MC rec'
mega_plot(h, exclude_peak=exclude_peak, range_2d=(1.25, 1.45), yrange_px=(1.34, 1.41), dphi_extra=dphi_extra / scale)
plt.savefig('05_12_sub_thresh_' + str(t).replace('.', '') +'.pdf')
plt.show()

t = 4.0
f= f_051_t4
plt.close('all')
f_re = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_4/output_reconstructed.root', 'read')
fig = plt.figure(figsize=figsize)
h = f.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t))
h.title = cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$\n' + pthresh + '$=\SI{' + str(t) + '}{GeV}$'
sub_px_re = extract_yield(f_re.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t)), exclude_peak=exclude_peak)[0]
sub_px_real = extract_yield(h)[0]
zyam_real = sub_px_real.Integral(sub_px_real.FindBin(1.3)-1, sub_px_real.FindBin(1.3)+1) /3.0
zyam_re = sub_px_re.Integral(sub_px_re.FindBin(1.3)-1, sub_px_re.FindBin(1.3)+1) /3.0
scale = zyam_re / zyam_real
print 'scale', scale 
dphi_extra=asrootpy(sub_px_re)
dphi_extra.title = 'MC rec'
mega_plot(h, exclude_peak=exclude_peak, range_2d=(1.25, 1.45), yrange_px=(1.36, 1.45), dphi_extra=dphi_extra / scale)
plt.savefig('05_12_sub_thresh_' + str(t).replace('.', '') +'.pdf')
plt.show()

t = 5.0
f= f_051_t5
plt.close('all')
f_re = root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_5/output_reconstructed.root', 'read')
fig = plt.figure(figsize=figsize)
h = f.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t))
h.title = cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$\n' + pthresh + '$=\SI{' + str(t) + '}{GeV}$'
sub_px_re = extract_yield(f_re.processed.subtracted_corrected.Get('Subtraction_thresh_'+str(t)), exclude_peak=exclude_peak)[0]
sub_px_real = extract_yield(h)[0]
zyam_real = sub_px_real.Integral(sub_px_real.FindBin(1.3)-1, sub_px_real.FindBin(1.3)+1) /3.0
zyam_re = sub_px_re.Integral(sub_px_re.FindBin(1.3)-1, sub_px_re.FindBin(1.3)+1) /3.0
scale = zyam_re / zyam_real
print 'scale', scale 
dphi_extra=asrootpy(sub_px_re)
dphi_extra.title = 'MC rec'
mega_plot(h, exclude_peak=exclude_peak, range_2d=(1.25, 1.45), yrange_px=(1.36, 1.45), dphi_extra=dphi_extra / scale)
plt.savefig('05_12_sub_thresh_' + str(t).replace('.', '') +'.pdf')
plt.show()
# Out:
# scale 0.900339628861
# scale 0.900339628861
# excess ridge yield per rad:
#  0.0489362304132 0.000962526682603
# scale 0.934298773641
# excess ridge yield per rad:
#  0.0533669979513 0.00157016671963
# scale 0.917761989907
# excess ridge yield per rad:
#  0.0628447408281 0.00284177218921
# scale 0.907621264994
# excess ridge yield per rad:
#  0.0604774778381 0.0049429939697
# scale 0.908095407362
# excess ridge yield per rad:
#  0.04852517342 0.00716920700194

# %% [markdown]
# ## Near side $\Delta \eta$: Compare reconstructed to measured

# %%
fs_real = {'0.0': root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_real.root', 'read'),
           '2.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_real.root', 'read'),
           '3.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_3/output_real.root', 'read'),
           '4.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_4/output_real.root', 'read'),
           '5.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_5/output_real.root', 'read')}
fs_reco = {'0.0': root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_reconstructed.root', 'read'),
           '2.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_reconstructed.root', 'read'),
           '3.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_3/output_reconstructed.root', 'read'),
           '4.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_4/output_reconstructed.root', 'read'),
           '5.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_5/output_reconstructed.root', 'read')}

from collections import OrderedDict
from ROOT import Double
from copy import deepcopy
err = Double()
yields_peak = []
yields_away = []
yields_near = []
ofs_real = OrderedDict(sorted(fs_real.items()))

plt.close('all')
figsize= (2.95 /2.5 * 5, 2.95/4*3)
fig, axs, = plt.subplots(1, 5, sharex=True, sharey=True, figsize=figsize, )
lns = []
for t, f_real, color, ax in zip(ofs_real.keys(), ofs_real.values(), colors, axs):
    h_reco = fs_reco.get(t).processed.subtracted_corrected.Get('Subtraction_thresh_'+t)
    h_real = f_real.processed.subtracted_corrected.Get('Subtraction_thresh_'+t)
    min_bin = h_real.projection_x().FindBin(1.3)
    zyam_real = h_real.projection_x().Integral(min_bin-1, min_bin+1) / (3 * 32)
    zyam_reco = h_reco.projection_x().Integral(min_bin-1, min_bin+1) / (3 * 32)
    scale = zyam_real / zyam_reco
    
    h_real.GetXaxis().SetRange(1, 17)
    h_real_py = asrootpy(h_real.projection_y()) / 17
    h_real_py.color = colors[0]
    lns.append(rplt.errorbar(h_real_py, axes=ax, label='Data', markersize=3))
    
    h_reco.GetXaxis().SetRange(1, 17)
    h_reco_py = asrootpy(h_reco.projection_y())* scale / 17
    h_reco_py.color = colors[1]
    lns.append(rplt.errorbar(h_reco_py, axes=ax, label='MC recon.', markersize=3))
    
    lower = h_reco_py.FindBin(-.8 + .01)
    upper = h_reco_py.FindBin(.8- .01)

    x = list(h_reco_py.x())[lower-1:upper]  # index != bin
    y1 = list(h_reco_py.y())[lower-1:upper]
    y2 = list(h_real_py.y())[lower-1:upper]
    ax.fill_between(x, y1, y2, color='grey', alpha='0.5')
   
    # using projection onto dphi for yield extraction
    # peak region
    y_range = (h_real_py.FindBin(-.8 + .01), h_real_py.FindBin(.8- .01))
    h_real.GetYaxis().SetRange(*y_range)
    h_real_px = asrootpy(h_real.projection_x()) / (y_range[1] - y_range[0] +1)
    h_reco.GetYaxis().SetRange(*y_range)
    h_reco_px = asrootpy(h_reco.projection_x()) / (y_range[1] - y_range[0] +1)
    diff_histo = h_real_px - h_reco_px * scale
    lower = diff_histo.FindBin(-pi/2 + .01)
    upper = diff_histo.FindBin(pi/2 - 0.01)
    yields_peak.append((diff_histo.IntegralAndError(lower, upper, err, 'width'), deepcopy(err)))
    
    # near side
    h_real.GetYaxis().SetRange(0,33); h_reco.GetYaxis().SetRange(0,33)
    diff_histo = extract_yield(h_real)[0] - extract_yield(h_reco)[0] * scale
    lower = diff_histo.FindBin(-pi/2 + .01)
    upper = diff_histo.FindBin(pi/2 - 0.01)
    yields_near.append((diff_histo.IntegralAndError(lower, upper, err, 'width'), deepcopy(err)))
    
    # away side
    h_real.GetYaxis().SetRange(0,33); h_reco.GetYaxis().SetRange(0,33)
    lower = diff_histo.FindBin(pi/2 + .01)
    upper = diff_histo.FindBin(3* pi/2 - 0.01)
    yields_away.append((diff_histo.IntegralAndError(lower, upper, err, 'width'), deepcopy(err)))

    plt.ylim(1.27, 1.45)
    plt.minorticks_on()
    ax.xaxis.major.locator.set_params(nbins=7)
    ax.set_xlabel(r'$\Delta\eta$')
    ax.set_title('Threshold \n$\SI{' + t + '}{GeV}$')
axs[0].legend(lns[0:2], [lab.get_label() for lab in lns[0:2]], loc=0)
axs[0].set_ylabel(r'$\frac{1}{N_{tr}}\frac{dN_{as}}{d\Delta \varphi}$'
                  '[rad$^{-1}$]')
plt.tight_layout(w_pad=.5)
fig.savefig('nearside_peak_yield.pdf')

# %% [markdown]
# __TODO:__
#
# * ~~add legend and labels~~
# * ~~Mark which one is which!~~

# %% [markdown]
# ### Extracted yields

# %%
plt.close('all')
figsize= (2.95,2.95)
fig = plt.figure(figsize=figsize)
ax  = plt.subplot(111)
# errors from non non closure in subtraction 
# thresh 5 missing atm!
abs_sys_errors_away = [0.0, .0127453, .021297, .031605, 0.05]
ax.errorbar([0, 2, 3, 4, 5], y=[y[0] for y in yields_peak], yerr=[y[1] for y in yields_peak],
             fmt='s', label=r'Peak region yield $|\Delta \eta| < 0.8$', markersize=7)
ax.errorbar([0, 2, 3, 4, 5], y=[y[0] for y in yields_near], yerr=[y[1] for y in yields_near],
             fmt='s', label=r'Near-side ridge yield $0.8<|\Delta\eta | < 1.6$', markersize=7)
ax.errorbar([0, 2, 3, 4, 5], y=[y[0] for y in yields_away],
            yerr=[y[1]+y_sys  for y, y_sys in zip(yields_away, abs_sys_errors_away)],
             fmt='s', label=r'Away-side ridge yield', markersize=7)
plt.xlim(-.5, 5.5)
plt.ylim(.00, .1) 
plt.ylabel(r'Ridge yields per $\Delta \eta$')
plt.xlabel(r'Threshold [GeV]')
plt.xticks( arange(6), (r'\SI{0}{GeV}', '', r'\SI{2}{GeV}', r'\SI{3}{GeV}', r'\SI{4}{GeV}', r'\SI{5}{GeV}'))
leg = ax.legend(loc='lower left')
leg.set_title(title='Ridge yields for ' +  cs[0] +'-' +cs[3] + '\n$0.5 <' +pta+r'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$', prop={"size": 9})
ax.yaxis.major.locator.set_params(nbins=5)
ax.minorticks_on()
fig.savefig('yield_evolution.pdf')
plt.show()

# %% [markdown]
# ### Last minute

# %%
f_12_t0 = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_real.root', 'read')
#f_051_t2 = root_open('/home/christian/msc/results/finals/go/output_real.root', 'read')
f_12_t3 = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_3/output_real.root', 'read')
f_12_t4 = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_4/output_real_no_st.root', 'read')

plt.close('all')
figsize= (2.95/2*3,2.95)

# Signal ratios:
plt.close('all')

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True, sharey=True, figsize=figsize, )
for a in fig.axes:
    a.set_xlabel(r'$\Delta \varphi [rad]$')
    #a.minorticks_on()
    #a.grid(True)
ax1.set_ylabel(r'Ratio $Y^{thresh} / Y^{no thresh}$')

hists_base = []
for c in range(0, 4):
    hists_base.append(asrootpy(f_12_t0.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_0.0')))


lns = []
t=2.0
ax = ax1

ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')

t=3.0
ax = ax2
f = f_12_t3
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t))) / hists_base[c]
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')

t=4.0
ax = ax3
f = f_12_t4
for c in range(0, 4):
    h = asrootpy(f.processed.total_yield_corrected.Get('total_yield_class_'+str(c)+'_thresh_'+str(t))) / hists_base[c]
    h_px = extract_yield(h)[0]
    h_px.set_title(cs[c][1:-1])
    h_px.color = colors[c]
    if c == 3:  # rebin peripheral
        h_px.Rebin()
        h_px.Scale(1.0 / 2.0)
    lns.append(rplt.errorbar(h_px, xerr=False, marker='d', axes=ax, markersize=4))
ax.set_title('Threshold $\SI{'+str(t)+'}{GeV}$')


fig.subplots_adjust(wspace=0)
#plt.setp([a.get_xticklabels() for a in fig.axes[:-1]], visible=False)
ax1.set_ylim(1.0, 1.45)
ax1.legend(loc=0, )
fig.tight_layout()
#fig.savefig('y_px_evolution_with_threshold_div_by_thresh0.pdf')
plt.show()
# Out:
# /home/christian/.virtualenvs/thesis/local/lib/python2.7/site-packages/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
#f_real = root_open('/home/christian/msc/results/140113/TPC_05-1_1-2/output_real.root', 'read')
f_real = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_real.root', 'read')
figsize= (2.95,2.95)

# Signal ratios:
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_real.processed.subtracted_corrected.Get('Subtraction_thresh_0.0')
h.title = '$(60-100\%) - (0-20\%)$\n$1 <' +pta+'< \SI{2}{GeV}<'+ptt+'<\SI{4}{GeV}$'
mega_plot(h, exclude_peak=True, plot_fit=False)#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
#plt.savefig('0512_subtraction.pdf')
plt.show()

h.Delete()

# %%
#f_real = root_open('/home/christian/msc/results/140113/TPC_05-1_1-2/output_real.root', 'read')
f_12_real = root_open('/home/christian/msc/results/131211/golden_05-1_1-2_ignore_no_trig/output_real.root', 'read')
figsize= (2.95,2.95)

# Signal ratios:

eclass = 0
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$0.5 <' +pta+'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$'
mega_plot(h, exclude_peak=True,)# range_2d=(1.0, 1.2), yrange_px=(1.02, 1.17))
plt.savefig('051_12_class' + str(eclass)+'.pdf')
plt.show()

eclass = 1
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$0.5 <' +pta+'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$'
mega_plot(h, exclude_peak=True,)# range_2d=(.6, .8), yrange_px=(.55, .8))#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
plt.savefig('051_12_class' + str(eclass)+'.pdf')
plt.show()

eclass = 2
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$0.5 <' +pta+'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$'
mega_plot(h, exclude_peak=True,)# range_2d=(.39, .59), yrange_px=(.34, .67))#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
plt.savefig('051_12_class' + str(eclass)+'.pdf')
plt.show()

eclass = 3
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_12_real.processed.total_yield_corrected.Get('total_yield_class_'+str(eclass)+'_thresh_0.0')
h.title = cs[eclass] + '\n$0.5 <' +pta+'< \SI{1}{GeV}<'+ptt+'<\SI{2}{GeV}$'
mega_plot(h, exclude_peak=True,)# range_2d=(.2, .4), yrange_px=(.15, .5))#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
plt.savefig('051_12_class' + str(eclass)+'.pdf')
plt.show()

h.drawstyle = 'surf1'

# %%
f_real = root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_4/output_real_no_st.root', 'read')
figsize= (2.95,2.95)

# Signal ratios:
plt.close('all')
fig = plt.figure(figsize=figsize)
h = f_real.processed.subtracted_corrected.Get('Subtraction_thresh_0.0')
h.title = '$(60-100\%) - (0-20\%)$\n$-2 cm < z_{vtx} < 0 cm$'
mega_plot(h, exclude_peak=True, plot_fit=False)#yrange_px=(0.994, 1.012), range_2d=(0.75, 1.07), xrange_py=(0.96, 1.05))
#plt.savefig('closure_S_peri_st.pdf')
plt.show()

h.Delete()

# %%
fs_real = {'0.0': root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_real.root', 'read'),
           #'2.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_real.root', 'read'),
           '3.0': root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_3/output_real.root', 'read'),
           '4.0': root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_4/output_real_no_st.root', 'read'),
           #'5.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_5/output_real.root', 'read')
           }
fs_reco = {'0.0': root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_0/output_reconstructed.root', 'read'),
           #'2.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_2/output_reconstructed.root', 'read'),
           '3.0': root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_3/output_reconstructed.root', 'read'),
           '4.0': root_open('/home/christian/msc/results/finals/golden_1-2_2-4_thresh_4/output_reconstructed.root', 'read'),
           #'5.0': root_open('/home/christian/msc/results/finals/golden_05-1_1-2_thresh_5/output_reconstructed.root', 'read')
           }

from collections import OrderedDict
from ROOT import Double
from copy import deepcopy
err = Double()
yields_peak = []
yields_away = []
yields_near = []
ofs_real = OrderedDict(sorted(fs_real.items()))

plt.close('all')
figsize= (2.95 /2.5 * 5, 2.95/4*3)
fig, axs, = plt.subplots(1, 5, sharex=True, sharey=True, figsize=figsize, )
lns = []
for t, f_real, color, ax in zip(ofs_real.keys(), ofs_real.values(), colors, axs):
    h_reco = fs_reco.get(t).processed.subtracted_corrected.Get('Subtraction_thresh_'+t)
    h_real = f_real.processed.subtracted_corrected.Get('Subtraction_thresh_'+t)
    min_bin = h_real.projection_x().FindBin(1.3)
    zyam_real = h_real.projection_x().Integral(min_bin-1, min_bin+1) / (3 * 32)
    zyam_reco = h_reco.projection_x().Integral(min_bin-1, min_bin+1) / (3 * 32)
    scale = zyam_real / zyam_reco
    
    h_real.GetXaxis().SetRange(1, 17)
    h_real_py = asrootpy(h_real.projection_y()) / 17
    h_real_py.color = colors[0]
    lns.append(rplt.errorbar(h_real_py, axes=ax, label='Data', markersize=3))
    
    h_reco.GetXaxis().SetRange(1, 17)
    h_reco_py = asrootpy(h_reco.projection_y())* scale / 17
    h_reco_py.color = colors[1]
    lns.append(rplt.errorbar(h_reco_py, axes=ax, label='MC recon.', markersize=3))
    
    lower = h_reco_py.FindBin(-.8 + .01)
    upper = h_reco_py.FindBin(.8- .01)

    x = list(h_reco_py.x())[lower-1:upper]  # index != bin
    y1 = list(h_reco_py.y())[lower-1:upper]
    y2 = list(h_real_py.y())[lower-1:upper]
    ax.fill_between(x, y1, y2, color='grey', alpha='0.5')
   
    # using projection onto dphi for yield extraction
    # peak region
    y_range = (h_real_py.FindBin(-.8 + .01), h_real_py.FindBin(.8- .01))
    h_real.GetYaxis().SetRange(*y_range)
    h_real_px = asrootpy(h_real.projection_x()) / (y_range[1] - y_range[0] +1)
    h_reco.GetYaxis().SetRange(*y_range)
    h_reco_px = asrootpy(h_reco.projection_x()) / (y_range[1] - y_range[0] +1)
    diff_histo = h_real_px - h_reco_px * scale
    lower = diff_histo.FindBin(-pi/2 + .01)
    upper = diff_histo.FindBin(pi/2 - 0.01)
    yields_peak.append((diff_histo.IntegralAndError(lower, upper, err, 'width'), deepcopy(err)))
    
    # near side
    h_real.GetYaxis().SetRange(0,33); h_reco.GetYaxis().SetRange(0,33)
    diff_histo = extract_yield(h_real)[0] - extract_yield(h_reco)[0] * scale
    lower = diff_histo.FindBin(-pi/2 + .01)
    upper = diff_histo.FindBin(pi/2 - 0.01)
    yields_near.append((diff_histo.IntegralAndError(lower, upper, err, 'width'), deepcopy(err)))
    
    # away side
    h_real.GetYaxis().SetRange(0,33); h_reco.GetYaxis().SetRange(0,33)
    lower = diff_histo.FindBin(pi/2 + .01)
    upper = diff_histo.FindBin(3* pi/2 - 0.01)
    yields_away.append((diff_histo.IntegralAndError(lower, upper, err, 'width'), deepcopy(err)))

    plt.ylim(1.27, 1.45)
    plt.minorticks_on()
    ax.xaxis.major.locator.set_params(nbins=7)
    ax.set_xlabel(r'$\Delta\eta$')
    ax.set_title('Threshold \n$\SI{' + t + '}{GeV}$')
axs[0].legend(lns[0:2], [lab.get_label() for lab in lns[0:2]], loc=0)
axs[0].set_ylabel(r'$\frac{1}{N_{tr}}\frac{dN_{as}}{d\Delta \varphi}$'
                  '[rad$^{-1}$]')
plt.tight_layout(w_pad=.5)
#fig.savefig('nearside_peak_yield.pdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-ebe37faedf3c> in <module>()
#      26 lns = []
#      27 for t, f_real, color, ax in zip(ofs_real.keys(), ofs_real.values(), colors, axs):
# ---> 28     h_reco = fs_reco.get(t).processed.subtracted_corrected.Get('Subtraction_thresh_'+t)
#      29     h_real = f_real.processed.subtracted_corrected.Get('Subtraction_thresh_'+t)
#      30     min_bin = h_real.projection_x().FindBin(1.3)
#
# /home/christian/.virtualenvs/thesis/local/lib/python2.7/site-packages/rootpy/io/file.pyc in __getattr__(self, attr)
#     177         if not thing:
#     178             raise AttributeError(
# --> 179                 "{0} has no attribute '{1}'".format(self, attr))
#     180         thing = asrootpy(thing)
#     181         if isinstance(thing, Directory):
#
# ...
